# %% [markdown]
# # Readme
#
# links to spotify documents and otehr resources
#     ° https://developer.spotify.com/documentation/web-api/reference/#/
#     ° https://developer.spotify.com/dashboard/applications/
#     ° https://www.base64encode.org/
#     ° https://open.spotify.com/artist/721C5U5rM8J0jjq6IQuSBK
#     ° https://developer.spotify.com/documentation/web-api/reference/#/

# %%
url_base = 'https://api.spotify.com/v1'

# %%
ep_artist = '/artists/{artistid}'

# %%
id_solstafir = '721C5U5rM8J0jjq6IQuSBK'
# se puede poner cualquier id de artista, este se obtiene de spotify en la barra de busqueda despues de /artists/xxxxxxxxx

# %%
url_base + ep_artist.format(artistid=id_solstafir)
# Out:
# 'https://api.spotify.com/v1/artists/721C5U5rM8J0jjq6IQuSBK'

# %%
import requests

# %%
#hacemos una request
r = requests.get(url_base + ep_artist.format(artistid=id_solstafir))

# %%
r.status_code
# Out:
# 401

# %% [markdown]
# #el 401 nos dice que no tenemos permisos para acceder a ese recurso

# %%
#revisamos el json que nos devuelve r
r.json()
# Out:
# {'error': {'status': 401, 'message': 'No token provided'}}

# %%
#accedemos a la url par aobtener el token
token_url = 'https://accounts.spotify.com/api/token'

# %%
params = {'grant_type': 'client_credentials'}

# %%
headrers = {'Authorization': 'Basic XXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXXX'}
#usar https://www.base64encode.org/ con client_id:client_secret (XXXXXX:YYYYY) de la pagina https://developer.spotify.com/dashboard/applications/

# %%
r = requests.post(token_url, data = params, headers = headrers)

# %%
r.status_code
# Out:
# 200

# %%
r.json()

# %%
#acceder al token directamente
token = r.json()['access_token']

# %%
token

# %%
header = {'Authorization': 'Bearer {}'.format(token)}

# %%
r = requests.get(url_base + ep_artist.format(artistid=id_solstafir), headers = header)

# %%
r.status_code
# Out:
# 200

# %%
r.json()
# Out:
# {'external_urls': {'spotify': 'https://open.spotify.com/artist/721C5U5rM8J0jjq6IQuSBK'},
#  'followers': {'href': None, 'total': 123395},
#  'genres': ['blackened screamo',
#   'icelandic black metal',
#   'icelandic metal',
#   'icelandic pop',
#   'pagan black metal',
#   'post-metal',
#   'viking black metal'],
#  'href': 'https://api.spotify.com/v1/artists/721C5U5rM8J0jjq6IQuSBK',
#  'id': '721C5U5rM8J0jjq6IQuSBK',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab6761610000e5ebb90a1aede7a026fbaed20013',
#    'width': 640},
#   {'height': 320,
#    'url': 'https://i.scdn.co/image/ab67616100005174b90a1aede7a026fbaed20013',
#    'width': 320},
#   {'height': 160,
#    'url': 'https://i.scdn.co/image/ab6761610000f178b90a1aede7a026fbaed20013',
#    'width': 160}],
#  'name': 'Sólstafir',
#  'popularity': 38,
#  'type': 'artist',
#  'uri': 'spotify:artist:721C5U5rM8J0jjq6IQuSBK'}

# %%
#Hacemos una bsuqueda con una url

url_busqueda = 'https://api.spotify.com/v1/search'

# %%
search_params = {'q': 'solstafir', 'type': 'artist', 'market': 'IS'}

# %%
busqueda = requests.get(url_busqueda, params = search_params, headers = header)

# %%
busqueda.status_code
# Out:
# 200

# %%
busqueda.json()
# Out:
# {'artists': {'href': 'https://api.spotify.com/v1/search?query=solstafir&type=artist&market=IS&offset=0&limit=20',
#   'items': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/721C5U5rM8J0jjq6IQuSBK'},
#     'followers': {'href': None, 'total': 123395},
#     'genres': ['blackened screamo',
#      'icelandic black metal',
#      'icelandic metal',
#      'icelandic pop',
#      'pagan black metal',
#      'post-metal',
#      'viking black metal'],
#     'href': 'https://api.spotify.com/v1/artists/721C5U5rM8J0jjq6IQuSBK',
#     'id': '721C5U5rM8J0jjq6IQuSBK',
#     'images': [{'height': 640,
#       'url': 'https://i.scdn.co/image/ab6761610000e5ebb90a1aede7a026fbaed20013',
#       'width': 640},
#      {'height': 320,
#       'url': 'https://i.scdn.co/image/ab67616100005174b90a1aede7a026fbaed20013',
#       'width': 320},
#      {'height': 160,
#       'url': 'https://i.scdn.co/image/ab6761610000f178b90a1aede7a026fbaed20013',
#       'width': 160}],
# ...

# %%
import pandas as pd

# %%
# creamos un dataframe con el resultado del json

df = pd.DataFrame(busqueda.json()['artists']['items'])

# %%
df
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/7...
# 1  {'spotify': 'https://open.spotify.com/artist/1...
# 2  {'spotify': 'https://open.spotify.com/artist/3...
# 3  {'spotify': 'https://open.spotify.com/artist/6...
#
#                          followers  \
# 0  {'href': None, 'total': 123395}
# 1    {'href': None, 'total': 8597}
# 2    {'href': None, 'total': 5060}
# 3    {'href': None, 'total': 4464}
#
#                                               genres  \
# 0  [blackened screamo, icelandic black metal, ice...
# 1  [icelandic folk, icelandic indie, icelandic po...
# 2                      [nordic orchestra, orchestra]
# 3  [classic icelandic pop, icelandic metal, icela...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/721C5U5rM8J...  721C5U5rM8J0jjq6IQuSBK
# 1  https://api.spotify.com/v1/artists/1SKQlvND1dW...  1SKQlvND1dW9m2zUpdDWBb
# ...

# %%
#ordenamos el dataframe por la columna popularity
df = df.sort_values(by = 'popularity', ascending = False)

# %%
df
# Out:
#                                        external_urls  \
# 0  {'spotify': 'https://open.spotify.com/artist/7...
# 1  {'spotify': 'https://open.spotify.com/artist/1...
# 2  {'spotify': 'https://open.spotify.com/artist/3...
# 3  {'spotify': 'https://open.spotify.com/artist/6...
#
#                          followers  \
# 0  {'href': None, 'total': 123395}
# 1    {'href': None, 'total': 8597}
# 2    {'href': None, 'total': 5060}
# 3    {'href': None, 'total': 4464}
#
#                                               genres  \
# 0  [blackened screamo, icelandic black metal, ice...
# 1  [icelandic folk, icelandic indie, icelandic po...
# 2                      [nordic orchestra, orchestra]
# 3  [classic icelandic pop, icelandic metal, icela...
#
#                                                 href                      id  \
# 0  https://api.spotify.com/v1/artists/721C5U5rM8J...  721C5U5rM8J0jjq6IQuSBK
# 1  https://api.spotify.com/v1/artists/1SKQlvND1dW...  1SKQlvND1dW9m2zUpdDWBb
# ...

# %%
#el que nos interesa el solo el primer elemento
df = df.iloc[0]

# %%
df
# Out:
# external_urls    {'spotify': 'https://open.spotify.com/artist/7...
# followers                          {'href': None, 'total': 123395}
# genres           [blackened screamo, icelandic black metal, ice...
# href             https://api.spotify.com/v1/artists/721C5U5rM8J...
# id                                          721C5U5rM8J0jjq6IQuSBK
# images           [{'height': 640, 'url': 'https://i.scdn.co/ima...
# name                                                     Sólstafir
# popularity                                                      38
# type                                                        artist
# uri                          spotify:artist:721C5U5rM8J0jjq6IQuSBK
# Name: 0, dtype: object

# %%
#por ahora solo queremos quedarnos con el id del artista
id_sols = df['id']

# %%
id_sols
# Out:
# '721C5U5rM8J0jjq6IQuSBK'

# %% [markdown]
# # Obteniendo la discografia

# %%
import base64

# %%
#creamos una funcion para renovar el token 
def get_token(client_id, client_secret):
    encoded = base64.b64encode(bytes('{}:{}'.format(client_id, client_secret), 'utf-8'))
    params = {'grant_type': 'client_credentials'}
    headers = {'Authorization': 'Basic {}'.format(encoded.decode('utf-8'))}
    r = requests.post('https://accounts.spotify.com/api/token', data = params, headers = headers)
    if r.status_code != 200:
        print('Error en la request', r.json())
        return None
    else:
        print('Tken válido por {} segundos'.format(r.json()['expires_in']))
        return r.json()['access_token']

# %%
client_id = 'XXXXXXXXXXXXXXXXXXXXXXXXX'
client_secret = 'XXXXXXXXXXXXX'

# %%
#pobamos las funcion anterior
token = get_token(clien_id, client_secret)
# Out:
# Tken válido por 3600 segundos

# %%
header = {'Authorization': 'Bearer {}'.format(token)}

# %%
id_sols
# Out:
# '721C5U5rM8J0jjq6IQuSBK'

# %%
ep_albums = '/artists/{id}/albums'

# %%
url_base + ep_albums.format(id=id_sols)
# Out:
# 'https://api.spotify.com/v1/artists/721C5U5rM8J0jjq6IQuSBK/albums'

# %%
params = {'country': 'IS'}

# %%
albums_sols = requests.get(url_base + ep_albums.format(id=id_sols), params = params, headers = header)

# %%
albums_sols.status_code
# Out:
# 200

# %%
albums_sols.json()
# Out:
# {'href': 'https://api.spotify.com/v1/artists/721C5U5rM8J0jjq6IQuSBK/albums?offset=0&limit=20&include_groups=album,single,compilation,appears_on&market=IS',
#  'items': [{'album_group': 'album',
#    'album_type': 'album',
#    'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/721C5U5rM8J0jjq6IQuSBK'},
#      'href': 'https://api.spotify.com/v1/artists/721C5U5rM8J0jjq6IQuSBK',
#      'id': '721C5U5rM8J0jjq6IQuSBK',
#      'name': 'Sólstafir',
#      'type': 'artist',
#      'uri': 'spotify:artist:721C5U5rM8J0jjq6IQuSBK'}],
#    'external_urls': {'spotify': 'https://open.spotify.com/album/7Gz2aaP3iC3eEzoNaMno4E'},
#    'href': 'https://api.spotify.com/v1/albums/7Gz2aaP3iC3eEzoNaMno4E',
#    'id': '7Gz2aaP3iC3eEzoNaMno4E',
#    'images': [{'height': 640,
#      'url': 'https://i.scdn.co/image/ab67616d0000b273ca6f61e4b859c3e4fdec46da',
#      'width': 640},
#     {'height': 300,
#      'url': 'https://i.scdn.co/image/ab67616d00001e02ca6f61e4b859c3e4fdec46da',
# ...

# %%
#nos quedamos solo con los items
albums_sols.json()['items']
# Out:
# [{'album_group': 'album',
#   'album_type': 'album',
#   'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/721C5U5rM8J0jjq6IQuSBK'},
#     'href': 'https://api.spotify.com/v1/artists/721C5U5rM8J0jjq6IQuSBK',
#     'id': '721C5U5rM8J0jjq6IQuSBK',
#     'name': 'Sólstafir',
#     'type': 'artist',
#     'uri': 'spotify:artist:721C5U5rM8J0jjq6IQuSBK'}],
#   'external_urls': {'spotify': 'https://open.spotify.com/album/7Gz2aaP3iC3eEzoNaMno4E'},
#   'href': 'https://api.spotify.com/v1/albums/7Gz2aaP3iC3eEzoNaMno4E',
#   'id': '7Gz2aaP3iC3eEzoNaMno4E',
#   'images': [{'height': 640,
#     'url': 'https://i.scdn.co/image/ab67616d0000b273ca6f61e4b859c3e4fdec46da',
#     'width': 640},
#    {'height': 300,
#     'url': 'https://i.scdn.co/image/ab67616d00001e02ca6f61e4b859c3e4fdec46da',
#     'width': 300},
#    {'height': 64,
#     'url': 'https://i.scdn.co/image/ab67616d00004851ca6f61e4b859c3e4fdec46da',
#     'width': 64}],
# ...

# %%
#vemos el primer album 
albums_sols.json()['items'][0]
# Out:
# {'album_group': 'album',
#  'album_type': 'album',
#  'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/721C5U5rM8J0jjq6IQuSBK'},
#    'href': 'https://api.spotify.com/v1/artists/721C5U5rM8J0jjq6IQuSBK',
#    'id': '721C5U5rM8J0jjq6IQuSBK',
#    'name': 'Sólstafir',
#    'type': 'artist',
#    'uri': 'spotify:artist:721C5U5rM8J0jjq6IQuSBK'}],
#  'external_urls': {'spotify': 'https://open.spotify.com/album/7Gz2aaP3iC3eEzoNaMno4E'},
#  'href': 'https://api.spotify.com/v1/albums/7Gz2aaP3iC3eEzoNaMno4E',
#  'id': '7Gz2aaP3iC3eEzoNaMno4E',
#  'images': [{'height': 640,
#    'url': 'https://i.scdn.co/image/ab67616d0000b273ca6f61e4b859c3e4fdec46da',
#    'width': 640},
#   {'height': 300,
#    'url': 'https://i.scdn.co/image/ab67616d00001e02ca6f61e4b859c3e4fdec46da',
#    'width': 300},
#   {'height': 64,
#    'url': 'https://i.scdn.co/image/ab67616d00004851ca6f61e4b859c3e4fdec46da',
#    'width': 64}],
#  'name': 'Endless Twilight of Codependent Love',
# ...

# %%
#veamos el nombre el album de todos los items
albums_sols.json()['items'][0]['name']
# Out:
# 'Endless Twilight of Codependent Love'

# %%
#  partir de album_sols.json()['items'] vamos a buscar para cada item los datos que nos interesan
#creamos un dataframe para guardar los datos

info_solstafir = pd.DataFrame()

for item in albums_sols.json()['items']:
    item_alb_id = []
    #guardamos todos los itemps en una lista
    item_alb_id.append(item['id'])
    item_alb_name = []
    item_alb_name.append(item['name'])
    item_alb_track_to = []
    item_alb_track_to.append(item['total_tracks'])
    item_alb_reali_date = []
    item_alb_reali_date.append(item['release_date'])
    #juntamos las listas con un for
    for i in item_alb_id:
        for j in item_alb_name:
            for k in item_alb_track_to:
                for l in item_alb_reali_date:
                    #guardamos i j k l en info_solstafir
                    info_solstafir = info_solstafir.append({'id': i, 'name': j, 'total_tracks': k, 'release_date': l}, ignore_index = True)
# Out:
# C:\Users\gmgar\AppData\Local\Temp\ipykernel_648\2097546196.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   info_solstafir = info_solstafir.append({'id': i, 'name': j, 'total_tracks': k, 'release_date': l}, ignore_index = True)
# C:\Users\gmgar\AppData\Local\Temp\ipykernel_648\2097546196.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   info_solstafir = info_solstafir.append({'id': i, 'name': j, 'total_tracks': k, 'release_date': l}, ignore_index = True)
# C:\Users\gmgar\AppData\Local\Temp\ipykernel_648\2097546196.py:22: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   info_solstafir = info_solstafir.append({'id': i, 'name': j, 'total_tracks': k, 'release_date': l}, ignore_index = True)
# ...

# %%
info_solstafir
# Out:
#                         id                                               name  \
# 0   7Gz2aaP3iC3eEzoNaMno4E               Endless Twilight of Codependent Love
# 1   4y0ReoVsLvfwFLRX5CcBsi                               Berdreyminn (Deluxe)
# 2   0HqcHMC54fcVF11WuN5fV2                                        Berdreyminn
# 3   3jUZIR2RRcuddKrbetFftv                                               Ótta
# 4   36yXQj7nPEk7jpvIXOcsJh              Í Blóði Og Anda (In Blood and Spirit)
# 5   6F2tCttIOIJzvlK4f6SE40                                     Svartir Sandar
# 6   1q1hSeqTm10Bq4lspbv6L8                                               Köld
# 7   6yvVBPCNlF5aBco71FbHV0                          Masterpiece Of Bitterness
# 8   44orwmOzYwPURoW2Yfnpfb               Endless Twilight of Codependent Love
# 9   4xHJON5VxzZqwPQi2sStIx                                Her Fall from Grace
# 10  0iKkEZpsHWqoF1O5ESG2fE                                            Drýsill
# ...

# %%
album_ep = '/albums/{album_id}'
album_params = {'market': 'IS'}

# %%
#seleccionamos un id
bnw_id = '3jUZIR2RRcuddKrbetFftv'

# %%
bnw = requests.get(url_base + album_ep.format(album_id=bnw_id)+'/tracks', params = album_params, headers = header)

# %%
bnw
# Out:
# <Response [200]>

# %%
bnw.json()
# Out:
# {'href': 'https://api.spotify.com/v1/albums/3jUZIR2RRcuddKrbetFftv/tracks?offset=0&limit=20&market=IS',
#  'items': [{'artists': [{'external_urls': {'spotify': 'https://open.spotify.com/artist/721C5U5rM8J0jjq6IQuSBK'},
#      'href': 'https://api.spotify.com/v1/artists/721C5U5rM8J0jjq6IQuSBK',
#      'id': '721C5U5rM8J0jjq6IQuSBK',
#      'name': 'Sólstafir',
#      'type': 'artist',
#      'uri': 'spotify:artist:721C5U5rM8J0jjq6IQuSBK'}],
#    'disc_number': 1,
#    'duration_ms': 524000,
#    'explicit': False,
#    'external_urls': {'spotify': 'https://open.spotify.com/track/5vkjx5WBPbAK7y3yUS3UnA'},
#    'href': 'https://api.spotify.com/v1/tracks/5vkjx5WBPbAK7y3yUS3UnA',
#    'id': '5vkjx5WBPbAK7y3yUS3UnA',
#    'is_local': False,
#    'is_playable': True,
#    'name': 'Lágnætti',
#    'preview_url': 'https://p.scdn.co/mp3-preview/a497b8a9833d0cb88773c32a40649d43230c0633?cid=ab89c76a89c44e5ebf2bb8fcc829aed7',
#    'track_number': 1,
#    'type': 'track',
# ...

# %%
#nos quedamos con el nombre de la cancion unicamente
bnw.json()['items'][0]['name']
# Out:
# 'Lágnætti'

# %%
[(track['id'], track['name']) for track in bnw.json()['items']]
# Out:
# [('5vkjx5WBPbAK7y3yUS3UnA', 'Lágnætti'),
#  ('2LJZE1yXy9SdglruufEDHG', 'Ótta'),
#  ('612b1EM4Q90ff5nWcci9Xi', 'Rismál'),
#  ('2LuYF8vX3LwZMRQiXm9w3W', 'Dagmál'),
#  ('258ihU9EiR7oG2a9tra6gR', 'Miðdegi'),
#  ('5yHIeYnj6yvavfyjoNhYyK', 'Nón'),
#  ('32slaVU9hlnlI7UDXE8xMP', 'Miðaftann'),
#  ('4aei6FwNGzOWs3tEWpRrFi', 'Náttmál')]

# %%
def obtener_discografia(artist_id, token, return_name=False, page_limit=50, country=None):
    url = f'https://api.spotify.com/v1/artists/{artist_id}/albums'
    header = {'Authorization': f'Bearer {token}'}
    params = {'limit': page_limit, 'market': country, 'offset': 0}

    lista_albumes = []
    r = requests.get(url, headers=header, params=params)
    if r.status_code != 200:
        print('Error en la request', r.json())
        return None
    if return_name:
        lista_albumes += [(item['id'], item['name']) for item in r.json()['items']]
    else:
        lista_albumes += [item['id'] for item in r.json()['items']]

    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header)
        if r.status_code != 200:
            return None
        else:
            print('Tken válido por {} segundos'.format(r.json()['expires_in']))
            return r.json()['access_token']

        if return_name:
            lista_albumes += [(item['id'], item['name']) for item in r.json()['items']]
    return lista_albumes

# %%
def obtener_tracks(album_id, token, return_name=False, page_limit=50, market=None):
    url = f'https://api.spotify.com/v1/albums/{album_id}/tracks'
    header = {'Authorization': f'Bearer {token}'}
    params = {'limit': page_limit, 'offset': 0, market: market}

    lista_tracks = []
    r = requests.get(url, headers=header, params=params)
    if r.status_code != 200:
        print('Error en la request', r.json())
        return None

    if return_name:
        lista_tracks += [(item['id'], item['name'])
                         for item in r.json()['items']]
    else:
        lista_tracks += [item['id'] for item in r.json()['items']]

    while r.json()['next']:
        r = requests.get(r.json()['next'], headers=header)
        if r.status_code != 200:
            return None
        else:
            print('Tken válido por {} segundos'.format(r.json()['expires_in']))
            return r.json()['access_token']

        if return_name:
            lista_tracks += [(item['id'], item['name'])
                             for item in r.json()['items']]
        else:
            lista_tracks += [item['id'] for item in r.json()['items']]

    return lista_tracks

# %%
for album in obtener_discografia(id_sols, token, return_name=True, country='IS'):
    print(album[1])
    for track in obtener_tracks(album[0], token, return_name=True, market='IS'):
        print('\t', track[1])
# Out:
# Endless Twilight of Codependent Love
# 	 Akkeri
# 	 Drýsill
# 	 Rökkur
# 	 Her Fall from Grace
# 	 Dionysus
# 	 Til Moldar
# 	 Alda Syndanna
# 	 Ör
# 	 Úlfur
# Berdreyminn (Deluxe)
# 	 Silfur-Refur
# 	 Ísafold
# 	 Hula
# 	 Nárós
# 	 Hvít Sæng
# 	 Dýrafjörður
# 	 Ambátt
# 	 Bláfjall
# 	 Svart Blóð
# 	 Samband I Berlin
# Berdreyminn
# 	 Silfur-Refur
# 	 Ísafold
# 	 Hula
# 	 Nárós
# 	 Hvít sæng
# 	 Dýrafjörður
# 	 Ambátt
# 	 Bláfjall
# Ótta
# 	 Lágnætti
# 	 Ótta
# 	 Rismál
# 	 Dagmál
# 	 Miðdegi
# 	 Nón
# 	 Miðaftann
# 	 Náttmál
# Í Blóði Og Anda (In Blood and Spirit)
# 	 Undir Jökli - Vetrarins Dauðu Sumarblom
# 	 Í Blóði og Anda
# 	 The Underworld Song
# 	 Tormentor
# 	 2000 Ár
# 	 Ei Við Munum Iðrast
# 	 Bitch in Black
# 	 Í Víking
# 	 Árstíðir Dauðans
# 	 Undir Jökli - 98 demo
# 	 Í Blóði og Anda - 98 demo
# 	 The Underworld Song - 98 Demo
# 	 Tormentor - 98 Demo
# 	 2000 Ar - 98 demo
# 	 Piano Song - 98 Demo
# 	 Ei Við Munum Iðrast - 97 demo
# 	 Bitch in Black - 97 Demo
# ...

# %%
preview_url = 'https://p.scdn.co/mp3-preview/a497b8a9833d0cb88773c32a40649d43230c0633?cid=ab89c76a89c44e5ebf2bb8fcc829aed7'

# %%
preview = requests.get(preview_url)
preview
# Out:
# <Response [200]>

# %%
import IPython.display as ipd

# %%
ipd.Audio(preview.content)
# Out:
#                 <audio  controls="controls" >
#                     <source src="data:audio/wav;base64,..." type="audio/wav" />
#                     Your browser does not support the audio element.
#                 </audio>
